# %%
import tensorflow as tf
import fiftyone.zoo as foz

# %%
dataset = foz.load_zoo_dataset(
    "open-images-v7",
    split="train",
    label_types=["detections"],
    classes=["Knife", "Scissors",  "Hammer", "Screwdriver"],
    max_samples=1000
)
# Out:
# ...
# Necessary images already downloaded
# Existing download of split 'train' is sufficient
# Loading existing dataset 'open-images-v7-train-1000'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
dataset = tf.keras.utils.image_dataset_from_directory(r"E:\DS\Deep learning\Objcet Detection Proect\fiftyone\open-images-v7\train")
# Out:
# Found 1000 files belonging to 3 classes.

# %%
import os

path = r"E:\DS\Deep learning\Objcet Detection Proect\fiftyone\open-images-v7\train"

print(os.path.exists(path))
# Out:
# True

# %%
from PIL import Image

img = Image.open(r"E:\DS\Deep learning\Objcet Detection Proect\fiftyone\open-images-v7\train\data\0a123e37d5ebbcb5.jpg")

print(img.format)
# Out:
# JPEG

# %%
import tensorflow as tf

img = tf.keras.utils.load_img(r"E:\DS\Deep learning\Objcet Detection Proect\fiftyone\open-images-v7\train\data\0a123e37d5ebbcb5.jpg")

print(img.size)
# Out:
# (1024, 707)

# %%
for images,label in dataset:
    data=tf.image.resize(images,(108,108))
    #print(data.shape)

# %%
import pandas as pd

df = pd.read_csv(r"E:\DS\Deep learning\Objcet Detection Proect\fiftyone\open-images-v7\train\labels\detections.csv")

#print(df.head())

# %%
import pandas as pd

df = pd.read_csv(r"E:\DS\Deep learning\Objcet Detection Proect\fiftyone\open-images-v7\train\labels\detections.csv")
names = pd.read_csv("class-descriptions-boxable.csv", header=None)
names.columns = ["LabelName", "ClassName"]
df = df.merge(names, on="LabelName", how="left")
